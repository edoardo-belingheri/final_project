# %% [markdown]
# # Edoardo

# %%
import pandas as pd
import numpy as np

# %%
# dati puliti
distribution_center_clean=pd.read_csv("..\\data\\clean_data\\distribution_center_clean.csv")
events_clean=pd.read_csv("..\\data\\clean_data\\events_clean.csv")
inventory_items_clean=pd.read_csv("..\\data\\clean_data\\inventory_items_clean.csv")
order_items_clean=pd.read_csv("..\\data\\clean_data\\order_items_clean.csv")
orders_clean=pd.read_csv("..\\data\\clean_data\\orders_clean.csv")
products_clean=pd.read_csv("..\\data\\clean_data\\products_clean.csv")
users_clean=pd.read_csv("..\\data\\clean_data\\users_clean.csv")
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15152\1772502959.py:3: DtypeWarning: Columns (0: user_id) have mixed types. Specify dtype option on import or set low_memory=False.
#   events_clean=pd.read_csv("..\\data\\clean_data\\events_clean.csv")

# %%
percorso_cartella = "..\\data\\clean_data\\"
nome_file  = ["distribution_center_clean",  "inventory_items_clean",
"order_items_clean", "orders_clean", "products_clean", "users_clean", "events_clean"]
diz={}
for nome in nome_file:
    percorso_file = percorso_cartella + nome + ".csv"
    diz[nome] = pd.read_csv(percorso_file)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16836\3026562969.py:7: DtypeWarning: Columns (0: user_id) have mixed types. Specify dtype option on import or set low_memory=False.
#   diz[nome] = pd.read_csv(percorso_file)

# %%
diz["events_clean"].sample(5)
# Out:
#                                   session_id  user_id  finish event_type  \
# 659624  cc48bd5c-fcd1-4df8-b8f6-9b756e6fcafd  36183.0      10   purchase
# 577937  97e39736-e48d-4249-b679-e4e1882e1af9  65620.0       5   purchase
# 178262  bde14014-7507-4a7d-919c-ceea2a069234  Unknown       2    product
# 276684  6d5225ef-d0eb-4eee-848f-970f25af6380  Unknown       3     cancel
# 669711  d4710f49-72c5-48fe-8950-1c86d70fd45f  82604.0      10   purchase
#
#        traffic_source        state        country
# 659624          Email        Henan          China
# 577937        Adwords      Jiangsu          China
# 178262          Email  Gyeonggi-do    South Korea
# 276684          Email        Anhui          China
# 669711          Email     Illinois  United States
