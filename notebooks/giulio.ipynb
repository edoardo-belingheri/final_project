# %% [markdown]
# # Giulio

# %%
# Importazione librerie
import numpy as np
import pandas as pd

# %%
percorso_cartella = "C:\\Users\\Utente\\Documents\\progetto finale\\final_project\\data\\initial_data\\"
nome_file  = [
    "Distribution Center", "events", "inventory_items",
    "order_items", "orders", "products", "Users"
] 
dfs = {}
for nome in nome_file:
    percorso_file = percorso_cartella + nome + ".csv"
    dfs[nome]  = pd.read_csv(percorso_file) #Qui assegno al dizionario vuoto una chiave e un valore dfs[chiave]= valore
    #dfs={"chiave": "valore"}

# %%
dfs_copia = {}
for dataframe in dfs:
    dfs_copia[dataframe] = dfs[dataframe].copy()

dfs_copia
# Out:
# {'Distribution Center':    id                                         name
#  0   3                                   Houston TX
#  1   7                              Philadelphia PA
#  2   5                               New Orleans LA
#  3   4                               Los Angeles CA
#  4   8                                    Mobile AL
#  5   1                                   Memphis TN
#  6   2                                   Chicago IL
#  7   6  Port Authority of New York/New Jersey NY/NJ
#  8  10                                  Savannah GA
#  9   9                                Charleston SC,
#  'events':                                   session_id  user_id  finish event_type  \
#  0       dc6fddfa-c512-4779-ad69-948227dea983      NaN       1    product
#  1       2e8747d9-ee1c-4287-949c-8257412cc31a      NaN       1    product
#  2       093fcc73-542a-42e0-8e04-2f4129186561      NaN       1    product
# ...
